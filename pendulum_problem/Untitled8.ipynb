# %%
import pickle
import matplotlib.pyplot as plt

# %%
a,b = pickle.load(open('cartpole_discrete_02.pkl', 'rb'))

# %%
plt.plot(a)
plt.plot(b)
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.savefig('Discrete_cartpole')
plt.show()
